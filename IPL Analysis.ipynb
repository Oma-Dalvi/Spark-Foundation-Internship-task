# %% [markdown]
# ### Spark Foundation

# %% [markdown]
# ### Intern :- Omkar Dalvi

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('whitegrid')
import plotly.express as px
# Out:
# C:\Users\omkar\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
deliveries = pd.read_csv("deliveries.csv")
deliveries.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
deliveries.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
def data_inv(deliveries):
    print('Number of Rows:',deliveries.shape[0]) # Total counts of Movies & TV-show
    print('dataset variables: ',deliveries.shape[1])    # gives Total count of column
    print('-'*70)
    print('dataset columns :\n') # All column_Name
    print(deliveries.columns)
    print('-'*70)
    print('data-type of each column: \n') # 
    print(deliveries.dtypes)
    print('-'*70)
    print('Missing rows in each column: \n')
    c=deliveries.isnull().sum()
    print(c[c>0])
    
data_inv(deliveries)
# Out:
# Number of Rows: 179078
# dataset variables:  21
# ----------------------------------------------------------------------
# dataset columns :
#
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')
# ----------------------------------------------------------------------
# data-type of each column:
#
# match_id             int64
# inning               int64
# batting_team        object
# bowling_team        object
# over                 int64
# ball                 int64
# batsman             object
# non_striker         object
# bowler              object
# is_super_over        int64
# wide_runs            int64
# bye_runs             int64
# legbye_runs          int64
# ...

# %%
data_inv(deliveries)
# Out:
# Number of Rows: 179078
# dataset variables:  21
# ----------------------------------------------------------------------
# dataset columns :
#
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')
# ----------------------------------------------------------------------
# data-type of each column:
#
# match_id             int64
# inning               int64
# batting_team        object
# bowling_team        object
# over                 int64
# ball                 int64
# batsman             object
# non_striker         object
# bowler              object
# is_super_over        int64
# wide_runs            int64
# bye_runs             int64
# legbye_runs          int64
# ...

# %% [markdown]
# ### Maximum Match Playing Team

# %%
plt.figure(figsize=(8,8))
deliveries["batting_team"].value_counts().plot(kind="bar")
plt.title("Region count bar plot")
plt.ylabel("Count")
plt.xlabel("Region")
plt.show()

# %% [markdown]
# ### Highest Wicket Takers

# %%
most_wickets=deliveries['dismissal_kind'].groupby(deliveries['bowler']).count().sort_values(ascending=False)

# %%
most_wickets=pd.DataFrame(most_wickets.head())
most_wickets.head()
most_wickets.rename(columns={'dismissal_kind':'wickets'},inplace=True)
most_wickets
# Out:
#                  wickets
# bowler
# SL Malinga           188
# DJ Bravo             168
# A Mishra             165
# Harbhajan Singh      161
# PP Chawla            156

# %%
most_wickets.plot.bar(legend=None)
plt.ylabel("Number Of Wickets Taken")
plt.title("Highest Wicket Takers Of IPL")
plt.show()

# %% [markdown]
# ### Highest Scoring Bastman

# %%
batsman_runs = deliveries.groupby("batsman")["batsman_runs"].sum().sort_values(ascending=False)
#Convert It Into A DataFrame
batsman_runs=pd.DataFrame(batsman_runs.head())
batsman_runs.head()
# Out:
#            batsman_runs
# batsman
# V Kohli            5434
# SK Raina           5415
# RG Sharma          4914
# DA Warner          4741
# S Dhawan           4632

# %%
batsman_runs.plot(kind='bar',legend=None)
plt.ylabel('Runs Scored')
plt.title("Highest Run Scorers Of IPL")
plt.show()

# %% [markdown]
# ### Best Fielders of IPL

# %%
fielder=deliveries.groupby('fielder')['dismissal_kind'].count().sort_values(ascending=False)
fielder=pd.DataFrame(fielder.head())
fielder.rename(columns={'dismissal_kind':'most_dismissals'},inplace=True)
fielder
# Out:
#                 most_dismissals
# fielder
# MS Dhoni                    159
# KD Karthik                  152
# RV Uthappa                  125
# SK Raina                    115
# AB de Villiers              114

# %%
fielder.plot.bar(legend=None)
plt.ylabel("")
plt.show()

# %% [markdown]
# ### Top Dismissed Player

# %%
plt.subplots()
sns.barplot(data=deliveries,x=deliveries['player_dismissed'].value_counts(),y=deliveries['player_dismissed'].value_counts().index,
           order = deliveries['player_dismissed'].value_counts().iloc[:5].index)
plt.show()

# %% [markdown]
# ### Total scored by each team in each match

# %%
run_analysis=deliveries.groupby(['match_id','inning','batting_team'])['total_runs'].sum()
run_analysis=pd.DataFrame(run_analysis).reset_index()
run_analysis
# Out:
#       match_id  inning                 batting_team  total_runs
# 0            1       1          Sunrisers Hyderabad         207
# 1            1       2  Royal Challengers Bangalore         172
# 2            2       1               Mumbai Indians         184
# 3            2       2       Rising Pune Supergiant         187
# 4            3       1                Gujarat Lions         183
# ...        ...     ...                          ...         ...
# 1523     11413       2               Delhi Capitals         170
# 1524     11414       1               Delhi Capitals         155
# 1525     11414       2          Chennai Super Kings         162
# 1526     11415       1               Mumbai Indians         152
# 1527     11415       2          Chennai Super Kings         157
#
# [1528 rows x 4 columns]

# %% [markdown]
# ### Detailed Run Analysis

# %%
detailed_run_analysis=pd.crosstab([deliveries['match_id'],deliveries['inning'],deliveries['batting_team']], deliveries['total_runs'],margins = False) 
score=np.array(run_analysis['total_runs'].values)
score=score.transpose()
detailed_run_analysis['final_Score']=score
detailed_run_analysis.head()
# Out:
# total_runs                                    0   1   2  3   4  5   6  7  8  \
# match_id inning batting_team
# 1        1      Sunrisers Hyderabad          26  62  10  1  17  0   9  0  0
#          2      Royal Challengers Bangalore  44  48   8  0  15  0   8  0  0
# 2        1      Mumbai Indians               41  55   5  0  12  1  11  0  0
#          2      Rising Pune Supergiant       29  59  10  0  18  0   6  0  0
# 3        1      Gujarat Lions                35  55   6  0  20  0   6  0  0
#
# total_runs                                   10  final_Score
# match_id inning batting_team
# 1        1      Sunrisers Hyderabad           0          207
#          2      Royal Challengers Bangalore   0          172
# 2        1      Mumbai Indians                0          184
#          2      Rising Pune Supergiant        0          187
# 3        1      Gujarat Lions                 0          183

# %% [markdown]
# ### Highest Scoring Team

# %%
Highest_scoring_teams=deliveries.groupby(['match_id','inning','batting_team'])['total_runs'].sum().sort_values(ascending=False).head(10)

# %%
Highest_scoring_teams=pd.DataFrame(Highest_scoring_teams)
Highest_scoring_teams=Highest_scoring_teams.reset_index()
Highest_scoring_teams.plot.bar(x="batting_team",y="total_runs",legend=None)
plt.title("Highest Scoring Teams")
plt.ylabel("Number Of Runs")
plt.xlabel("Team Name")
Highest_scoring_teams
# Out:
#    match_id  inning                 batting_team  total_runs
# 0       411       1  Royal Challengers Bangalore         263
# 1      7937       1        Kolkata Knight Riders         250
# 2       620       1  Royal Challengers Bangalore         248
# 3       206       1          Chennai Super Kings         246
# 4     11338       1        Kolkata Knight Riders         241
# 5        61       1          Chennai Super Kings         240
# 6       562       1  Royal Challengers Bangalore         235
# 7     11147       1          Sunrisers Hyderabad         233
# 8       296       1              Kings XI Punjab         232
# 9     11339       1          Sunrisers Hyderabad         232

# %% [markdown]
# #### Seperating innings

# %%
inn1 = deliveries.loc[deliveries['inning']==1]
inn2 = deliveries.loc[deliveries['inning']==2]
inn3 = deliveries.loc[deliveries['inning']==3]
inn4 = deliveries.loc[deliveries['inning']==4]

# %%
inn1.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
inn2.head()
# Out:
#      match_id  inning                 batting_team         bowling_team  over  \
# 125         1       2  Royal Challengers Bangalore  Sunrisers Hyderabad     1
# 126         1       2  Royal Challengers Bangalore  Sunrisers Hyderabad     1
# 127         1       2  Royal Challengers Bangalore  Sunrisers Hyderabad     1
# 128         1       2  Royal Challengers Bangalore  Sunrisers Hyderabad     1
# 129         1       2  Royal Challengers Bangalore  Sunrisers Hyderabad     1
#
#      ball        batsman    non_striker   bowler  is_super_over  ...  \
# 125     1       CH Gayle  Mandeep Singh  A Nehra              0  ...
# 126     2  Mandeep Singh       CH Gayle  A Nehra              0  ...
# 127     3  Mandeep Singh       CH Gayle  A Nehra              0  ...
# 128     4  Mandeep Singh       CH Gayle  A Nehra              0  ...
# 129     5  Mandeep Singh       CH Gayle  A Nehra              0  ...
#
#      bye_runs  legbye_runs  noball_runs  penalty_runs  batsman_runs  \
# ...

# %% [markdown]
# #### Total Runs of Each Team in Inning Based on Match id, Inning,batting_team

# %%
inn1=inn1.groupby(['match_id','inning','batting_team'])['total_runs'].sum()
inn2=inn2.groupby(['match_id','inning','batting_team'])['total_runs'].sum()
inn3=inn3.groupby(['match_id','inning','batting_team'])['total_runs'].sum()
inn4=inn4.groupby(['match_id','inning','batting_team'])['total_runs'].sum()

# %%
inn1.head()
# Out:
# match_id  inning  batting_team
# 1         1       Sunrisers Hyderabad            207
# 2         1       Mumbai Indians                 184
# 3         1       Gujarat Lions                  183
# 4         1       Rising Pune Supergiant         163
# 5         1       Royal Challengers Bangalore    157
# Name: total_runs, dtype: int64

# %%
inn2.head()
# Out:
# match_id  inning  batting_team
# 1         2       Royal Challengers Bangalore    172
# 2         2       Rising Pune Supergiant         187
# 3         2       Kolkata Knight Riders          184
# 4         2       Kings XI Punjab                164
# 5         2       Delhi Daredevils               142
# Name: total_runs, dtype: int64

# %%
#Inning 1 And Inning 2 Are Normal Innings,Grouped Them Together Based On Match_Id
all_matches=pd.merge(inn1,inn2,on='match_id')

#Inning 3 And Inning 4 Are Super Over So Grouped Them Separately Based On Match_id
super_overs=pd.merge(inn3,inn4,on='match_id')

# %%
all_matches
# Out:
#           total_runs_x  total_runs_y
# match_id
# 1                  207           172
# 2                  184           187
# 3                  183           184
# 4                  163           164
# 5                  157           142
# ...                ...           ...
# 11347              143           137
# 11412              136           140
# 11413              171           170
# 11414              155           162
# 11415              152           157
#
# [754 rows x 2 columns]

# %%
super_overs
# Out:
#           total_runs_x  total_runs_y
# match_id
# 34                  11             6
# 126                 15            18
# 190                  9            10
# 388                 20            15
# 401                 15            11
# 476                 11            11
# 536                 15             6

# %%
# Comaparing Scores of both teams and storein in new columns

lst = []

for i in range(len(all_matches)):
    a = all_matches['total_runs_x'].iloc[i]
    b = all_matches['total_runs_y'].iloc[i]
    if a>b:
        lst.append("team1 won")
    elif a<b:
        lst.append("team2 won")
    elif a==b:
        lst.append("draw")
all_matches['result'] = lst
all_matches = pd.DataFrame(all_matches)
all_matches
# Out:
#           total_runs_x  total_runs_y     result
# match_id
# 1                  207           172  team1 won
# 2                  184           187  team2 won
# 3                  183           184  team2 won
# 4                  163           164  team2 won
# 5                  157           142  team1 won
# ...                ...           ...        ...
# 11347              143           137  team1 won
# 11412              136           140  team2 won
# 11413              171           170  team1 won
# 11414              155           162  team2 won
# 11415              152           157  team2 won
#
# [754 rows x 3 columns]

# %%
# Comparing Super over score of both Teams

lst1 = []
for i in range(len(super_overs)):
    a1 = all_matches['total_runs_x'].iloc[i]
    b1 = all_matches['total_runs_y'].iloc[i]
    if a1>b1:
        lst1.append("team1 won")
    elif a1<b1:
        lst1.append("team2 won")
    elif a1==b1:
        lst1.append("draw")

super_overs['super_overs_result']=lst1
super_overs=pd.DataFrame(super_overs)
super_overs
# Out:
#           total_runs_x  total_runs_y super_overs_result
# match_id
# 34                  11             6          team1 won
# 126                 15            18          team2 won
# 190                  9            10          team2 won
# 388                 20            15          team2 won
# 401                 15            11          team1 won
# 476                 11            11          team2 won
# 536                 15             6          team2 won

# %%
# Renaming Column name of Super over data

super_overs = super_overs.rename(columns={'total_runs_x':'total_runs_x1',
                                         'total_runs_y':'total_runs_y1'})
super_overs
# Out:
#           total_runs_x1  total_runs_y1 super_overs_result
# match_id
# 34                   11              6          team1 won
# 126                  15             18          team2 won
# 190                   9             10          team2 won
# 388                  20             15          team2 won
# 401                  15             11          team1 won
# 476                  11             11          team2 won
# 536                  15              6          team2 won

# %%
#Creating super_over_result column into all_matches dataframe

all_matches['super_over_result']=super_overs['super_overs_result']
all_matches=all_matches.fillna('No Super Over')
all_matches.reset_index(inplace=True)
all_matches
# Out:
#      match_id  total_runs_x  total_runs_y     result super_over_result
# 0           1           207           172  team1 won     No Super Over
# 1           2           184           187  team2 won     No Super Over
# 2           3           183           184  team2 won     No Super Over
# 3           4           163           164  team2 won     No Super Over
# 4           5           157           142  team1 won     No Super Over
# ..        ...           ...           ...        ...               ...
# 749     11347           143           137  team1 won     No Super Over
# 750     11412           136           140  team2 won     No Super Over
# 751     11413           171           170  team1 won     No Super Over
# 752     11414           155           162  team2 won     No Super Over
# 753     11415           152           157  team2 won     No Super Over
#
# [754 rows x 5 columns]

# %%
# Storing Unique Match id along with Team Names

batt=[]
m_id1=[]
for i in range(0,150458):
    if deliveries['batting_team'].iloc[i]!=deliveries['batting_team'].iloc[i+1]:
        batt.append(deliveries['batting_team'].iloc[i])
        m_id1.append(deliveries['match_id'].iloc[i])
    else:
        pass

# %%
m_id1=pd.DataFrame(m_id1)
m_id1['Team 1']=batt

# %%
m_id1.rename(columns={0:'match_id'})
# Out:
#       match_id                       Team 1
# 0            1          Sunrisers Hyderabad
# 1            1  Royal Challengers Bangalore
# 2            2               Mumbai Indians
# 3            2       Rising Pune Supergiant
# 4            3                Gujarat Lions
# ...        ...                          ...
# 1263       633  Royal Challengers Bangalore
# 1264       634          Sunrisers Hyderabad
# 1265       634        Kolkata Knight Riders
# 1266       635                Gujarat Lions
# 1267       636          Sunrisers Hyderabad
#
# [1268 rows x 2 columns]

# %%
bat1=[]
for i in range(0,1268,2):
    bat1.append(m_id1.loc[i])

# %%
#Teams Who Played 2nd Inning
bat2=[]
for i in range(1,1268,2):
    bat2.append(m_id1.loc[i])

# %%
#Converting List To DataFrames
bat1=pd.DataFrame(bat1)
bat2=pd.DataFrame(bat2)

# %%
bat1
# Out:
#         0                       Team 1
# 0       1          Sunrisers Hyderabad
# 2       2               Mumbai Indians
# 4       3                Gujarat Lions
# 6       4       Rising Pune Supergiant
# 8       5  Royal Challengers Bangalore
# ...   ...                          ...
# 1258  631        Kolkata Knight Riders
# 1260  632             Delhi Daredevils
# 1262  633                Gujarat Lions
# 1264  634          Sunrisers Hyderabad
# 1266  635                Gujarat Lions
#
# [634 rows x 2 columns]

# %%
bat2
# Out:
#         0                       Team 1
# 1       1  Royal Challengers Bangalore
# 3       2       Rising Pune Supergiant
# 5       3        Kolkata Knight Riders
# 7       4              Kings XI Punjab
# 9       5             Delhi Daredevils
# ...   ...                          ...
# 1259  631          Sunrisers Hyderabad
# 1261  632  Royal Challengers Bangalore
# 1263  633  Royal Challengers Bangalore
# 1265  634        Kolkata Knight Riders
# 1267  636          Sunrisers Hyderabad
#
# [634 rows x 2 columns]

# %%
bat1.rename(columns={0:"match_id"},inplace=True)
bat2.rename(columns={0:"match_id"},inplace=True)
batting=bat1.merge(bat2,on='match_id')
batting
# Out:
#      match_id                     Team 1_x                     Team 1_y
# 0           1          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1           2               Mumbai Indians       Rising Pune Supergiant
# 2           3                Gujarat Lions        Kolkata Knight Riders
# 3           4       Rising Pune Supergiant              Kings XI Punjab
# 4           5  Royal Challengers Bangalore             Delhi Daredevils
# ..        ...                          ...                          ...
# 627       630               Mumbai Indians                Gujarat Lions
# 628       631        Kolkata Knight Riders          Sunrisers Hyderabad
# 629       632             Delhi Daredevils  Royal Challengers Bangalore
# 630       633                Gujarat Lions  Royal Challengers Bangalore
# 631       634          Sunrisers Hyderabad        Kolkata Knight Riders
#
# [632 rows x 3 columns]

# %%
batting.rename(columns={'Team 1_x':'Team 1','Team 1_y':'Team 2'},inplace=True)
batting
# Out:
#      match_id                       Team 1                       Team 2
# 0           1          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1           2               Mumbai Indians       Rising Pune Supergiant
# 2           3                Gujarat Lions        Kolkata Knight Riders
# 3           4       Rising Pune Supergiant              Kings XI Punjab
# 4           5  Royal Challengers Bangalore             Delhi Daredevils
# ..        ...                          ...                          ...
# 627       630               Mumbai Indians                Gujarat Lions
# 628       631        Kolkata Knight Riders          Sunrisers Hyderabad
# 629       632             Delhi Daredevils  Royal Challengers Bangalore
# 630       633                Gujarat Lions  Royal Challengers Bangalore
# 631       634          Sunrisers Hyderabad        Kolkata Knight Riders
#
# [632 rows x 3 columns]

# %%
final=batting.merge(all_matches,on='match_id')
final
# Out:
#      match_id                       Team 1                       Team 2  \
# 0           1          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1           2               Mumbai Indians       Rising Pune Supergiant
# 2           3                Gujarat Lions        Kolkata Knight Riders
# 3           4       Rising Pune Supergiant              Kings XI Punjab
# 4           5  Royal Challengers Bangalore             Delhi Daredevils
# ..        ...                          ...                          ...
# 627       630               Mumbai Indians                Gujarat Lions
# 628       631        Kolkata Knight Riders          Sunrisers Hyderabad
# 629       632             Delhi Daredevils  Royal Challengers Bangalore
# 630       633                Gujarat Lions  Royal Challengers Bangalore
# 631       634          Sunrisers Hyderabad        Kolkata Knight Riders
#
#      total_runs_x  total_runs_y     result super_over_result
# ...

# %%
# Changing Team1 won to wining Team Name 

for i in range(len(final)):
    if final['result'].iloc[i]=='team1 won':
        final['result'].iloc[i]=final['Team 1'].iloc[i]
# Out:
# C:\Users\omkar\Anaconda3\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
# Changing Team2 won to wining Team Name 


for i in range(len(final)):
    if final['result'].iloc[i]=='team2 won':
        final['result'].iloc[i]=final['Team 2'].iloc[i]

# %%
# Chaning Team 2 Won to winning Team Name in Super Over

for i in range(len(final)):
    if final['super_over_result'].iloc[i]=='team2 won':
        final['super_over_result'].iloc[i]=final['Team 2'].iloc[i]

# %%
# Chaning Team 1 Won to winning Team Name in Super Over


for i in range(len(final)):
    if final['super_over_result'].iloc[i]=='team1 won':
        final['super_over_result'].iloc[i]=final['Team 1'].iloc[i]

# %%
#Changing Name from Draw to Team Name Based On Super_over_result Winner
for i in range(len(final)):
    if final['result'].iloc[i]=='draw':
        final['result'].iloc[i]=final['super_over_result'].iloc[i]

# %%
final.rename(columns={'total_runs_x':'Team 1 Score','total_runs_y':"Team 2 Score"},inplace=True)
final
# Out:
#      match_id                       Team 1                       Team 2  \
# 0           1          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1           2               Mumbai Indians       Rising Pune Supergiant
# 2           3                Gujarat Lions        Kolkata Knight Riders
# 3           4       Rising Pune Supergiant              Kings XI Punjab
# 4           5  Royal Challengers Bangalore             Delhi Daredevils
# ..        ...                          ...                          ...
# 627       630               Mumbai Indians                Gujarat Lions
# 628       631        Kolkata Knight Riders          Sunrisers Hyderabad
# 629       632             Delhi Daredevils  Royal Challengers Bangalore
# 630       633                Gujarat Lions  Royal Challengers Bangalore
# 631       634          Sunrisers Hyderabad        Kolkata Knight Riders
#
#      Team 1 Score  Team 2 Score                       result super_over_result
# ...

# %%
top5=final['result'].value_counts().head()
top5
# Out:
# Mumbai Indians                 82
# Kolkata Knight Riders          79
# Royal Challengers Bangalore    76
# Delhi Daredevils               75
# Kings XI Punjab                72
# Name: result, dtype: int64

# %%
top5.plot.bar(color='green')
plt.title("Top 5 Teams With Highest Wins")
plt.ylabel("Number Of Wins")
plt.show()
